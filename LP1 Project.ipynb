# %% [markdown]
# # Exploring the Indian Startup Ecosystem: Data Analysis and Strategic Insights
#
# In this project, our team dives into the world of Indian startups. Using data analysis, we will explore funding trends, regional disparities, and investor behavior and preferences. We aim to find what is working, what is not, and where the opportunities lie. The insights we gain will help guide our strategy as we venture into the Indian startup ecosystem, making informed decisions in this dynamic market.
#
#
# #NULL HYPOTHESIS: There has been no significant increase in the amounts of funding received by Indian startups between 2018 and 2021
#
#
# #ALTERNATIVE HYPOTHESIS: The amounts of funding received by Indian startups have increased significantly between 2018 to 2021.
#
#
#
# Analytical Questions:
# 1. What top 10 sectors have received the highest amount of funding
# 2. What top 10 sectors have received lowest amounts of funding
# 3. What is the average amount of funding a startup received
# 3. Which funding stages tend to receive the highest amount of funding
# 4. Which Regions(Location of headquarters) in India have the highest concentration of successfully funded startups
# 6. What is the overall trend in funding for Indian startups over the past years

# %%
# %pip install pyodbc
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# %pip install python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
#import necesssary modules
import pyodbc
from dotenv import dotenv_values
import pandas as pd
import numpy as np
import warnings

warnings.filterwarnings('ignore')

# %%
# Load environment variables from .env file into a dictionary
environment_variables=dotenv_values('.env')

# Get the values for the credentials you set in the '.env' file
database = environment_variables.get("DATABASE")
server = environment_variables.get("SERVER")
username = environment_variables.get("USERNAME")
password = environment_variables.get("PASSWORD")

#code for connection 
connection_string=f"DRIVER={{SQL Server}};SERVER={server};DATABASE={database};UID={username};PWD={password}"

# %%
# Use the connect method of the pyodbc library and pass in the connection string

connection = pyodbc.connect(connection_string)

# %% [markdown]
# # Getting the data

# %%
#write query statement to get dateset

query = "Select * from dbo.LP1_startup_funding2020"
data = pd.read_sql(query, connection)
 
data.head()
# Out:
#   Company_Brand  Founded HeadQuarter              Sector  \
# 0    Aqgromalin   2019.0     Chennai            AgriTech
# 1      Krayonnz   2019.0   Bangalore              EdTech
# 2  PadCare Labs   2018.0        Pune  Hygiene management
# 3         NCOME   2020.0   New Delhi              Escrow
# 4    Gramophone   2016.0      Indore            AgriTech
#
#                                         What_it_does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# ...

# %%
#get data shape
data.shape
# Out:
# (1055, 10)

# %%
#get data info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1055 non-null   object
#  1   Founded        842 non-null    float64
#  2   HeadQuarter    961 non-null    object
#  3   Sector         1042 non-null   object
#  4   What_it_does   1055 non-null   object
#  5   Founders       1043 non-null   object
#  6   Investor       1017 non-null   object
#  7   Amount         801 non-null    float64
#  8   Stage          591 non-null    object
#  9   column10       2 non-null      object
# dtypes: float64(2), object(8)
# memory usage: 82.6+ KB

# %%
#load second dataset

query2 = "Select * from dbo.LP1_startup_funding2021"
data1 = pd.read_sql(query2, connection)
 
data1.head()
# Out:
#     Company_Brand  Founded HeadQuarter          Sector  \
# 0  Unbox Robotics   2019.0   Bangalore      AI startup
# 1          upGrad   2015.0      Mumbai          EdTech
# 2     Lead School   2012.0      Mumbai          EdTech
# 3         Bizongo   2015.0      Mumbai  B2B E-commerce
# 4        FypMoney   2021.0    Gurugram         FinTech
#
#                                         What_it_does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# ...

# %%
data1.shape
# Out:
# (1209, 9)

# %%
#load  third dataset
data2 = pd.read_csv('startup_funding2019.csv')
data2.head()
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 0  Bombay Shaving      NaN         NaN        Ecommerce
# 1       Ruangguru   2014.0      Mumbai           Edtech
# 2        Eduisfun      NaN      Mumbai           Edtech
# 3        HomeLane   2014.0     Chennai  Interior design
# 4        Nu Genes   2004.0   Telangana         AgriTech
#
#                                         What it does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
# ...

# %%
#load fourth dataset

data3 = pd.read_csv('startup_funding2018.csv')
data3.head()
# Out:
#       Company Name                                           Industry  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#   Round/Series       Amount                          Location  \
# 0         Seed       250000       Bangalore, Karnataka, India
# 1         Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2     Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3        Angel      2000000       Noida, Uttar Pradesh, India
# 4         Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                        About Company
# 0  TheCollegeFever is a hub for fun, fiesta and f...
# 1  A startup which aggregates milk from dairy far...
# ...

# %% [markdown]
# # Data Cleaning and EDA

# %% [markdown]
# Duplicates are dropped to ensure the uniqueness of the data

# %%
#drop duplicates in first dataset if any

data = data.drop_duplicates()
data.head()
# Out:
#   Company_Brand  Founded HeadQuarter              Sector  \
# 0    Aqgromalin   2019.0     Chennai            AgriTech
# 1      Krayonnz   2019.0   Bangalore              EdTech
# 2  PadCare Labs   2018.0        Pune  Hygiene management
# 3         NCOME   2020.0   New Delhi              Escrow
# 4    Gramophone   2016.0      Indore            AgriTech
#
#                                         What_it_does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# ...

# %% [markdown]
# Unecessary columns are dropped to improve data quality by ensuring that only relevant data is used

# %%
#drop unnecesary columns ('column10)

data = data.drop(columns='column10')
data.head()
# Out:
#   Company_Brand  Founded HeadQuarter              Sector  \
# 0    Aqgromalin   2019.0     Chennai            AgriTech
# 1      Krayonnz   2019.0   Bangalore              EdTech
# 2  PadCare Labs   2018.0        Pune  Hygiene management
# 3         NCOME   2020.0   New Delhi              Escrow
# 4    Gramophone   2016.0      Indore            AgriTech
#
#                                         What_it_does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# ...

# %% [markdown]
# A new column which shows the year the funding was received is added in order to enable time series analysis when the data sets are concatenated into one

# %%
#create a new column called Year Funded and fill with 2020

value_to_fill = 2020
data['Year Funded'] = value_to_fill
data
# Out:
#      Company_Brand  Founded HeadQuarter              Sector  \
# 0       Aqgromalin   2019.0     Chennai            AgriTech
# 1         Krayonnz   2019.0   Bangalore              EdTech
# 2     PadCare Labs   2018.0        Pune  Hygiene management
# 3            NCOME   2020.0   New Delhi              Escrow
# 4       Gramophone   2016.0      Indore            AgriTech
# ...            ...      ...         ...                 ...
# 1050  Leverage Edu      NaN       Delhi              Edtech
# 1051         EpiFi      NaN        None             Fintech
# 1052       Purplle   2012.0      Mumbai           Cosmetics
# 1053        Shuttl   2015.0       Delhi           Transport
# 1054         Pando   2017.0     Chennai            Logitech
#
#                                            What_it_does  \
# 0                          Cultivating Ideas for Profit
# 1     An academy-guardian-scholar centric ecosystem ...
# 2      Converting bio-hazardous waste to harmless waste
# ...

# %%
#Get data shape to know number of rows and columns

data1.shape
# Out:
# (1209, 9)

# %%
#drop duplicates if any for the second dataset to ensure uniqueness of dataset

data1 = data1.drop_duplicates()
data1
# Out:
#        Company_Brand  Founded HeadQuarter                 Sector  \
# 0     Unbox Robotics   2019.0   Bangalore             AI startup
# 1             upGrad   2015.0      Mumbai                 EdTech
# 2        Lead School   2012.0      Mumbai                 EdTech
# 3            Bizongo   2015.0      Mumbai         B2B E-commerce
# 4           FypMoney   2021.0    Gurugram                FinTech
# ...              ...      ...         ...                    ...
# 1204        Gigforce   2019.0    Gurugram  Staffing & Recruiting
# 1205          Vahdam   2015.0   New Delhi       Food & Beverages
# 1206    Leap Finance   2019.0   Bangalore     Financial Services
# 1207    CollegeDekho   2015.0    Gurugram                 EdTech
# 1208          WeRize   2019.0   Bangalore     Financial Services
#
#                                            What_it_does  \
# 0     Unbox Robotics builds on-demand AI-driven ware...
# 1        UpGrad is an online higher education platform.
# ...

# %%
#create a new column called Year Funded and fill with 2021

value_to_fill1 = 2021
data1['Year Funded'] = value_to_fill1
data1
# Out:
#        Company_Brand  Founded HeadQuarter                 Sector  \
# 0     Unbox Robotics   2019.0   Bangalore             AI startup
# 1             upGrad   2015.0      Mumbai                 EdTech
# 2        Lead School   2012.0      Mumbai                 EdTech
# 3            Bizongo   2015.0      Mumbai         B2B E-commerce
# 4           FypMoney   2021.0    Gurugram                FinTech
# ...              ...      ...         ...                    ...
# 1204        Gigforce   2019.0    Gurugram  Staffing & Recruiting
# 1205          Vahdam   2015.0   New Delhi       Food & Beverages
# 1206    Leap Finance   2019.0   Bangalore     Financial Services
# 1207    CollegeDekho   2015.0    Gurugram                 EdTech
# 1208          WeRize   2019.0   Bangalore     Financial Services
#
#                                            What_it_does  \
# 0     Unbox Robotics builds on-demand AI-driven ware...
# 1        UpGrad is an online higher education platform.
# ...

# %% [markdown]
# similar datasets are concatenated to make analysis easy and effective

# %%
#concat first and second dataset 

df = pd.concat([data, data1])
df
# Out:
#      Company_Brand  Founded HeadQuarter                 Sector  \
# 0       Aqgromalin   2019.0     Chennai               AgriTech
# 1         Krayonnz   2019.0   Bangalore                 EdTech
# 2     PadCare Labs   2018.0        Pune     Hygiene management
# 3            NCOME   2020.0   New Delhi                 Escrow
# 4       Gramophone   2016.0      Indore               AgriTech
# ...            ...      ...         ...                    ...
# 1204      Gigforce   2019.0    Gurugram  Staffing & Recruiting
# 1205        Vahdam   2015.0   New Delhi       Food & Beverages
# 1206  Leap Finance   2019.0   Bangalore     Financial Services
# 1207  CollegeDekho   2015.0    Gurugram                 EdTech
# 1208        WeRize   2019.0   Bangalore     Financial Services
#
#                                            What_it_does  \
# 0                          Cultivating Ideas for Profit
# 1     An academy-guardian-scholar centric ecosystem ...
# ...

# %%
# get data info to be sure of what we are working with

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2242 entries, 0 to 1208
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  2242 non-null   object
#  1   Founded        2028 non-null   float64
#  2   HeadQuarter    2147 non-null   object
#  3   Sector         2229 non-null   object
#  4   What_it_does   2242 non-null   object
#  5   Founders       2226 non-null   object
#  6   Investor       2143 non-null   object
#  7   Amount         1986 non-null   object
#  8   Stage          1359 non-null   object
#  9   Year Funded    2242 non-null   int64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 192.7+ KB

# %%
df.head()
# Out:
#   Company_Brand  Founded HeadQuarter              Sector  \
# 0    Aqgromalin   2019.0     Chennai            AgriTech
# 1      Krayonnz   2019.0   Bangalore              EdTech
# 2  PadCare Labs   2018.0        Pune  Hygiene management
# 3         NCOME   2020.0   New Delhi              Escrow
# 4    Gramophone   2016.0      Indore            AgriTech
#
#                                         What_it_does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# ...

# %%
pd.set_option('display.max_rows', 10)

# %% [markdown]
# Amount column is converted to a numeric value to enable aggregations. Errors are coerced to NaN to prevent code errors

# %%
# Convert 'Amount' column to numeric, coercing errors to NaN

df['Amount'] = pd.to_numeric(df['Amount'], errors='coerce')

# %%
#get data head to preview the dataframe

df.head()
# Out:
#   Company_Brand  Founded HeadQuarter              Sector  \
# 0    Aqgromalin   2019.0     Chennai            AgriTech
# 1      Krayonnz   2019.0   Bangalore              EdTech
# 2  PadCare Labs   2018.0        Pune  Hygiene management
# 3         NCOME   2020.0   New Delhi              Escrow
# 4    Gramophone   2016.0      Indore            AgriTech
#
#                                         What_it_does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# ...

# %%
# Set the display options to show float values without scientific notation. This removes the decimal notation from the year values

pd.set_option('display.float_format', lambda x: '%.0f' % x)

# %%
# Rename the column from 'Amount' to 'Amount($)'

df.rename(columns={'Amount': 'Amount($)'}, inplace=True)

# %%
df.head()
# Out:
#   Company_Brand  Founded HeadQuarter              Sector  \
# 0    Aqgromalin     2019     Chennai            AgriTech
# 1      Krayonnz     2019   Bangalore              EdTech
# 2  PadCare Labs     2018        Pune  Hygiene management
# 3         NCOME     2020   New Delhi              Escrow
# 4    Gramophone     2016      Indore            AgriTech
#
#                                         What_it_does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# ...

# %%
# Rename the column from 'What_it_does' to 'What it does'

df.rename(columns={'What_it_does': 'What it does'}, inplace=True)

# %%
# Rename the column from 'Company_Brand' to 'Company Brand'

df.rename(columns={'Company_Brand': 'Company Brand'}, inplace=True)

# %%
df.head()
# Out:
#   Company Brand  Founded HeadQuarter              Sector  \
# 0    Aqgromalin     2019     Chennai            AgriTech
# 1      Krayonnz     2019   Bangalore              EdTech
# 2  PadCare Labs     2018        Pune  Hygiene management
# 3         NCOME     2020   New Delhi              Escrow
# 4    Gramophone     2016      Indore            AgriTech
#
#                                         What it does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# ...

# %%
#get a view of the third dataset

data2.head()
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 0  Bombay Shaving      NaN         NaN        Ecommerce
# 1       Ruangguru     2014      Mumbai           Edtech
# 2        Eduisfun      NaN      Mumbai           Edtech
# 3        HomeLane     2014     Chennai  Interior design
# 4        Nu Genes     2004   Telangana         AgriTech
#
#                                         What it does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
# ...

# %%
#create a new column called Year Funded and fill with 2019

value_to_fill2 = 2019
data2['Year Funded'] = value_to_fill2
data2
# Out:
#       Company/Brand  Founded HeadQuarter                   Sector  \
# 0    Bombay Shaving      NaN         NaN                Ecommerce
# 1         Ruangguru     2014      Mumbai                   Edtech
# 2          Eduisfun      NaN      Mumbai                   Edtech
# 3          HomeLane     2014     Chennai          Interior design
# 4          Nu Genes     2004   Telangana                 AgriTech
# ..              ...      ...         ...                      ...
# 84     Infra.Market      NaN      Mumbai                Infratech
# 85              Oyo     2013    Gurugram              Hospitality
# 86       GoMechanic     2016       Delhi  Automobile & Technology
# 87           Spinny     2015       Delhi               Automobile
# 88  Ess Kay Fincorp      NaN   Rajasthan                  Banking
#
#                                          What it does  \
# 0          Provides a range of male grooming products
# 1   A learning platform that provides topic-based ...
# ...

# %%
# Remove currency symbols from data2 to enable aggregations
data2['Amount($)'] = data2['Amount($)'].str.replace('$', '')
data2
# Out:
#       Company/Brand  Founded HeadQuarter                   Sector  \
# 0    Bombay Shaving      NaN         NaN                Ecommerce
# 1         Ruangguru     2014      Mumbai                   Edtech
# 2          Eduisfun      NaN      Mumbai                   Edtech
# 3          HomeLane     2014     Chennai          Interior design
# 4          Nu Genes     2004   Telangana                 AgriTech
# ..              ...      ...         ...                      ...
# 84     Infra.Market      NaN      Mumbai                Infratech
# 85              Oyo     2013    Gurugram              Hospitality
# 86       GoMechanic     2016       Delhi  Automobile & Technology
# 87           Spinny     2015       Delhi               Automobile
# 88  Ess Kay Fincorp      NaN   Rajasthan                  Banking
#
#                                          What it does  \
# 0          Provides a range of male grooming products
# 1   A learning platform that provides topic-based ...
# ...

# %%
# Rename the column from 'Company/Brand' to 'Company Brand'

data2.rename(columns={'Company/Brand': 'Company Brand'}, inplace=True)

# %%
data2.head()
# Out:
#     Company Brand  Founded HeadQuarter           Sector  \
# 0  Bombay Shaving      NaN         NaN        Ecommerce
# 1       Ruangguru     2014      Mumbai           Edtech
# 2        Eduisfun      NaN      Mumbai           Edtech
# 3        HomeLane     2014     Chennai  Interior design
# 4        Nu Genes     2004   Telangana         AgriTech
#
#                                         What it does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
# ...

# %%
#Concatenate df with third dataset

df1 = pd.concat([df, data2])
df1
# Out:
#       Company Brand  Founded HeadQuarter                   Sector  \
# 0        Aqgromalin     2019     Chennai                 AgriTech
# 1          Krayonnz     2019   Bangalore                   EdTech
# 2      PadCare Labs     2018        Pune       Hygiene management
# 3             NCOME     2020   New Delhi                   Escrow
# 4        Gramophone     2016      Indore                 AgriTech
# ..              ...      ...         ...                      ...
# 84     Infra.Market      NaN      Mumbai                Infratech
# 85              Oyo     2013    Gurugram              Hospitality
# 86       GoMechanic     2016       Delhi  Automobile & Technology
# 87           Spinny     2015       Delhi               Automobile
# 88  Ess Kay Fincorp      NaN   Rajasthan                  Banking
#
#                                          What it does  \
# 0                        Cultivating Ideas for Profit
# 1   An academy-guardian-scholar centric ecosystem ...
# ...

# %% [markdown]
# We check for the number of null values to know what we are dealing with

# %%
#Check for number of null values

df1.isnull().sum()
# Out:
# Company Brand       0
# Founded           243
# HeadQuarter       114
# Sector             18
# What it does        0
# Founders           19
# Investor           99
# Amount($)        1443
# Stage             929
# Year Funded         0
# dtype: int64

# %%
#check for unique values for each column

df1.nunique()
# Out:
# Company Brand    1797
# Founded            34
# HeadQuarter       123
# Sector            502
# What it does     2186
# Founders         1980
# Investor         1777
# Amount($)         350
# Stage              62
# Year Funded         3
# dtype: int64

# %%
data3.head()
# Out:
#       Company Name                                           Industry  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#   Round/Series       Amount                          Location  \
# 0         Seed       250000       Bangalore, Karnataka, India
# 1         Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2     Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3        Angel      2000000       Noida, Uttar Pradesh, India
# 4         Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                        About Company
# 0  TheCollegeFever is a hub for fun, fiesta and f...
# 1  A startup which aggregates milk from dairy far...
# ...

# %% [markdown]
# The aim is to make the last dataset (startup_funding2018) look like the other datasets in terms of structure so that concatenation will be done

# %%
#the location is split and only the first city is maintained in order to make it look like the other datasets

data3['Location'] = data3['Location'].str.split(', ').str[0]
data3
# Out:
#           Company Name                                           Industry  \
# 0      TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1      Happy Cow Dairy                               Agriculture, Farming
# 2           MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3          PayMe India                        Financial Services, FinTech
# 4             Eunimart                 E-Commerce Platforms, Retail, SaaS
# ..                 ...                                                ...
# 521              Udaan   B2B, Business Development, Internet, Marketplace
# 522  Happyeasygo Group                                    Tourism, Travel
# 523             Mombay         Food and Beverage, Food Delivery, Internet
# 524         Droni Tech                             Information Technology
# 525            Netmeds         Biotechnology, Health Care, Pharmaceutical
#
#     Round/Series       Amount   Location  \
# ...

# %%
# Get information about the dataset, including data types and missing values
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company Name   526 non-null    object
#  1   Industry       526 non-null    object
#  2   Round/Series   526 non-null    object
#  3   Amount         526 non-null    object
#  4   Location       526 non-null    object
#  5   About Company  526 non-null    object
# dtypes: object(6)
# memory usage: 24.8+ KB

# %% [markdown]
# Amount values for the fourth dataset is converted from Rupees to dollars to ensure consistency and validity of dataset

# %%
def extract_currency(amount):
    if pd.notna(amount):  # Check if the value is not NaN
        currencies = ['₹', '$']
        amount_str = str(amount)  # Convert to string to handle float values

        for currency in currencies:
            if currency in amount_str:
                return currency

    return None

# Applying the function to the 'Amount' column
data3['Currency'] = data3['Amount'].apply(extract_currency)

data3
# Out:
#           Company Name                                           Industry  \
# 0      TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1      Happy Cow Dairy                               Agriculture, Farming
# 2           MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3          PayMe India                        Financial Services, FinTech
# 4             Eunimart                 E-Commerce Platforms, Retail, SaaS
# ..                 ...                                                ...
# 521              Udaan   B2B, Business Development, Internet, Marketplace
# 522  Happyeasygo Group                                    Tourism, Travel
# 523             Mombay         Food and Beverage, Food Delivery, Internet
# 524         Droni Tech                             Information Technology
# 525            Netmeds         Biotechnology, Health Care, Pharmaceutical
#
#     Round/Series       Amount   Location  \
# ...

# %%
# Define exchange rate for Rupees to Dollars (The average INR/USD exchange rate for 2018 is 0.01461 US Dollars per Indian Rupee.)

rupees_to_dollars_rate = 0.01461

# %%
# Convert to numeric, considering currency
data3['Amount'] = pd.to_numeric(data3['Amount'].replace('[\\₹,$]', '', regex=True), errors='coerce')

# Perform the currency conversion
data3['Amount'] = data3['Amount'] * rupees_to_dollars_rate 

data3
# Out:
#           Company Name                                           Industry  \
# 0      TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1      Happy Cow Dairy                               Agriculture, Farming
# 2           MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3          PayMe India                        Financial Services, FinTech
# 4             Eunimart                 E-Commerce Platforms, Retail, SaaS
# ..                 ...                                                ...
# 521              Udaan   B2B, Business Development, Internet, Marketplace
# 522  Happyeasygo Group                                    Tourism, Travel
# 523             Mombay         Food and Beverage, Food Delivery, Internet
# 524         Droni Tech                             Information Technology
# 525            Netmeds         Biotechnology, Health Care, Pharmaceutical
#
#     Round/Series  Amount   Location  \
# 0           Seed    3652  Bangalore
# ...

# %% [markdown]
# Certain columns are renamed to ensure that data3's structure is similar to df1 in order for concatenation to be done

# %%
#change column name from 'Company Name' to 'Company Brand' 
data3.rename(columns={'Company Name': 'Company Brand'}, inplace=True)

#Change column name from 'Location' to 'HeadQuarter
data3.rename(columns={'Location': 'HeadQuarter'}, inplace=True)

#Change column name from ' Round/Series' to 'Stage'
data3.rename(columns={'Round/Series': 'Stage'}, inplace=True)

#Change column name from 'About Company' to 'What it does'
data3.rename(columns={'About Company': 'What it does'}, inplace=True)

#Change column name from ' Industry' to 'Sector'
data3.rename(columns={ 'Industry': 'Sector'}, inplace=True)

# Add dollar sign($) to 'Amount' column
data3.rename(columns={'Amount' : 'Amount($)'}, inplace=True)

# %%
data3.head()
# Out:
#      Company Brand                                             Sector  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#       Stage  Amount($) HeadQuarter  \
# 0      Seed       3652   Bangalore
# 1      Seed     584400      Mumbai
# 2  Series A     949650     Gurgaon
# 3     Angel      29220       Noida
# 4      Seed        NaN   Hyderabad
#
#                                         What it does Currency
# 0  TheCollegeFever is a hub for fun, fiesta and f...     None
# 1  A startup which aggregates milk from dairy far...        ₹
# 2          Leading Online Loans Marketplace in India        ₹
# 3  PayMe India is an innovative FinTech organizat...     None
# ...

# %%
# Drop Currency column since it is of no use

data3 = data3.drop(columns = 'Currency')
data3
# Out:
#          Company Brand                                             Sector  \
# 0      TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1      Happy Cow Dairy                               Agriculture, Farming
# 2           MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3          PayMe India                        Financial Services, FinTech
# 4             Eunimart                 E-Commerce Platforms, Retail, SaaS
# ..                 ...                                                ...
# 521              Udaan   B2B, Business Development, Internet, Marketplace
# 522  Happyeasygo Group                                    Tourism, Travel
# 523             Mombay         Food and Beverage, Food Delivery, Internet
# 524         Droni Tech                             Information Technology
# 525            Netmeds         Biotechnology, Health Care, Pharmaceutical
#
#         Stage  Amount($) HeadQuarter  \
# 0        Seed       3652   Bangalore
# ...

# %%
#create a new column called Year Funded and fill with 2018

value_to_fill1 = 2018
data3['Year Funded'] = value_to_fill1
data3
# Out:
#          Company Brand                                             Sector  \
# 0      TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1      Happy Cow Dairy                               Agriculture, Farming
# 2           MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3          PayMe India                        Financial Services, FinTech
# 4             Eunimart                 E-Commerce Platforms, Retail, SaaS
# ..                 ...                                                ...
# 521              Udaan   B2B, Business Development, Internet, Marketplace
# 522  Happyeasygo Group                                    Tourism, Travel
# 523             Mombay         Food and Beverage, Food Delivery, Internet
# 524         Droni Tech                             Information Technology
# 525            Netmeds         Biotechnology, Health Care, Pharmaceutical
#
#         Stage  Amount($) HeadQuarter  \
# 0        Seed       3652   Bangalore
# ...

# %%
# check for unique values
data3.nunique()
# Out:
# Company Brand    525
# Sector           405
# Stage             21
# Amount($)        158
# HeadQuarter       50
# What it does     524
# Year Funded        1
# dtype: int64

# %%
#concatenate the last dataset with the df1

data_final= pd.concat([df1 , data3])

data_final
# Out:
#          Company Brand  Founded HeadQuarter  \
# 0           Aqgromalin     2019     Chennai
# 1             Krayonnz     2019   Bangalore
# 2         PadCare Labs     2018        Pune
# 3                NCOME     2020   New Delhi
# 4           Gramophone     2016      Indore
# ..                 ...      ...         ...
# 521              Udaan      NaN   Bangalore
# 522  Happyeasygo Group      NaN     Haryana
# 523             Mombay      NaN      Mumbai
# 524         Droni Tech      NaN      Mumbai
# 525            Netmeds      NaN     Chennai
#
#                                                Sector  \
# 0                                            AgriTech
# 1                                              EdTech
# 2                                  Hygiene management
# 3                                              Escrow
# 4                                            AgriTech
# ..                                                ...
# ...

# %% [markdown]
# Sector column is dealt with to make the dataset more concise and easy to work with. To do this, a function is created and the re module is used to search for specific keywords for a particular sector.

# %%
#get unique values from sector column
data_final['Sector'].unique()
# Out:
# array(['AgriTech', 'EdTech', 'Hygiene management', 'Escrow',
#        'Networking platform', 'FinTech', 'Crowdsourcing',
#        'Food & Bevarages', 'HealthTech', 'Fashion startup',
#        'Food Industry', 'Food Delivery', 'Virtual auditing startup',
#        'E-commerce', 'Gaming', 'Work fulfillment', 'AI startup',
#        'Telecommunication', 'Logistics', 'Tech Startup', 'Sports',
#        'Retail', 'Medtech', 'Tyre management', 'Cloud company',
#        'Software company', 'Venture capitalist', 'Renewable player',
#        'IoT startup', 'SaaS startup', 'Aero company', 'Marketing company',
#        'Retail startup', 'Co-working Startup', 'Finance company',
#        'Tech company', 'Solar Monitoring Company',
#        'Video sharing platform', 'Gaming startup',
#        'Video streaming platform', 'Consumer appliances',
#        'Blockchain startup', 'Conversational AI platform', 'Real Estate',
#        'SaaS platform', 'AI platform', 'Fusion beverages', 'HR Tech',
# ...

# %%
# Standardize specific enteries in the Sector column to ensure consistency


data_final['Sector'] = data_final['Sector'].replace ({
'AgriTech':  'Agriculture Technology(AgriTech)', 
'EdTech':  'Education Technology(EdTech)', 
'Hygiene management':  'Healthcare and Biotech',
 'Escrow':  'Finance and Fintech',
 'Networking platform':  'Technology and Software',
 'FinTech':  'Finance and Fintech', 
'Crowdsourcing':  'Technology and Software',
'Food & Bevarages':  'Travel and Hospitality', 
'HealthTech':  'Healthcare and Biotech', 
'Fashion startup':  'Fashion and Lifestyle',
'Food Industry':  'Travel and Hospitality',
 'Food Delivery':  'Travel and Hospitality', 
'Virtual auditing startup':  'Finance and Fintech',
'E-commerce':  'E-commerce', 
'Gaming':  'Media and Entertainment', 
 'AI startup':  'Technology and Software',
'Telecommunication':  'Media and Entertainment',
 'Logistics':  'Transportation and Logistics',
 'Tech Startup':  'Technology and Software', 
'Sports':  'Media and Entertainment',
'Retail':  'E-commerce', 
'Medtech':  'Healthcare and Biotech',
 'Tyre management':  'Transportation and Logistics',
 'Cloud company':  'Technology & Software',
'Software company':  'Technology and Software',
 'Venture capitalist':  'Finance and Fintech', 
'Renewable player':  'Renewable Energy',
'IoT startup':  'Manufacturing and Hardware', 
'SaaS startup':  'Technology & Software', 

'Marketing company':  'E-commerce',
'Retail startup':  'E-commerce', 

 'Finance company':  'Finance and Fintech',
'Tech company':  'Technology and Software',
 'Solar Monitoring Company':  'Renewable Energy',
'Video sharing platform':  'Media and Entertainment',
 'Gaming startup':  'Media and Entertainment',
'Video streaming platform':  'Media and Entertainment', 
'Consumer appliances':  'E-commerce',
'Blockchain startup':  'Emerging Technologies',
 'Conversational AI platform':  'Technology & Software', 
'Real Estate':  'Real Estate Tech (PropTech)',
'SaaS platform':  'Technology & Software', 
'AI platform':  'Technology & Software', 
'Fusion beverages':  'Travel and Hospitality',
 'HR Tech':  'E-commerce',
'Job portal':  'E-commerce',
 'Hospitality':  'Travel and Hospitality', 
'Digital Media':  'Media and Entertainment', 
 
'Spacetech':  'Space Tech',
 'Transportation':  'Transportation and Logistics',                   
'Trading platform':  'E-commerce',
 'AI Company':  'Technology & Software',
 'Photonics startup':  'Media and Entertainment',
'Entertainment':  'Media and Entertainment', 
'Cosmetics':  'Fashion and Lifestyle',
 'Scanning app':  'Technology & Software',
 'Skincare startup':  'Fashion and Lifestyle',
'Food and Beverages':  'Travel and Hospitality', 
'Biotechnology company':  'Healthcare and Biotech', 
'FoodTech':  'Travel and Hospitality',
'Proptech':  'Real Estate Tech (PropTech)', 
'CleanTech':  'Renewable Energy',

 'Healthcare':  'Healthcare and Biotech',

 'Beverages':  'Travel and Hospitality',
 'Social Media':  'Media and Entertainment',
 'Automobiles':  'Transportation and Logistics',
 
'Video platform':  'Media and Entertainment',
 'Edtech':  'Education Technology(EdTech)', 
'Fertility tech':  'Healthcare and Biotech',
'Luxury car startup':  'Transportation and Logistics',
 'FM':  'Media and Entertainment',
 'Food':  'Travel and Hospitality',
 'Nutrition sector':  'Healthcare and Biotech',
  'Fintech':  'Finance and Fintech',

'Commercial Real Estate':  'Real Estate Tech (PropTech)',
 'Consumer service':  'E-commerce',
 'Consumer goods':  'E-commerce',
  'MarTech':  'Marketing and Advertising Technology',
  'Biotechnology, Health Care, Pharmaceutical':  'Healthcare and Biotech',

  'Financial Services':  'Finance and Fintech',

'Networking':  'E-commerce',
 'Marketing and Advertising Technology':  'Marketing and Advertising Technology',
  'Advertisement':  'Marketing and Advertising Technology',
  'Content creation':  'Media and Entertainment',

  'Food and Beverage, Food Delivery, Internet':  'Travel and Hospitality',



'3D Printing, Manufacturing, Product Design':  'Marketing and Advertising Technology',
 'â€”':  'Other Sectors',
 'Accomodation':  'Real Estate Tech (PropTech)',
  'Accounting, Apps, FinTech':  'Finance and Fintech',
  'Accounting, Business Information Systems, Business Travel, Finance, SaaS':  'Finance and Fintech',
  'Ad-tech':  'Marketing and Advertising Technology',
'Advertising, Artificial Intelligence, Digital Media, iOS, Location Based Services, News, Video, Video on Demand, Video Streaming':  'Marketing and Advertising Technology',
 'Advertising, Consulting, Digital Marketing':  'Marketing and Advertising Technology',
  'Advertising, Human Resources, Marketing':  'Marketing and Advertising Technology',
  'Advertising, Internet, Marketing':  'Marketing and Advertising Technology',
  'Advisory firm':  'Legaltech and Govtech',

 
'Aeorspace':  'Space Tech',
 'Aero company':  'Space Tech',
 'Aerospace':  'Space Tech',
  'Aerospace':  'Space Tech',
  'Agri tech':  'Agriculture Technology(AgriTech)',
  'Agriculture':  'Agriculture Technology(AgriTech)',
'Agriculture':  'Agriculture Technology(AgriTech)',
 'Agriculture, AgTech, Artificial Intelligence, Internet of Things, Machine Learning':  'Agriculture Technology(AgriTech)',
  'Agriculture, AgTech, Manufacturing':  'Agriculture Technology(AgriTech)',
  'Agriculture, Analytics, Big Data, Farming':  'Agriculture Technology(AgriTech)',
  'Agriculture, Farmers Market, Farming':  'Agriculture Technology(AgriTech)',


   
'Agriculture, Farming':  'Agriculture Technology(AgriTech)',
 'Agriculture, Mobile':  'Agriculture Technology(AgriTech)',
 'Agritech':  'Agriculture Technology(AgriTech)',
    
'Agritech startup':  'Agriculture Technology(AgriTech)',
 'Agritech/Commerce':  'Agriculture Technology(AgriTech)',
 'AgTech, B2B, Supply Chain Management':  'Agriculture Technology(AgriTech)',
  
   
'Agriculture, Farming':  'Agriculture Technology(AgriTech)',
 'Agriculture, Mobile':  'Agriculture Technology(AgriTech)',
 'Agritech':  'Agriculture Technology(AgriTech)',
    # AI REPLACEMENT
'AI':  'Technology and Software',
 'AI & Data science':  'Technology and Software',
 'AI & Debt':  'Technology and Software',
 'AI & Deep learning':  'Technology and Software',
 'AI & Media':  'Technology and Software',
 'AI & Tech':  'Technology and Software',
 'AI Chatbot':  'Technology and Software',
 'AI company':  'Technology and Software',
 'AI health':  'Technology and Software',
 'AI Platform':  'Technology and Software',
 'AI Robotics':  'Technology and Software',
 'AI Startup':  'Technology and Software',


'Ecommerce':     'E-commerce',
'E-commerce':     'E-commerce',
'E-commerce & AR':     'E-commerce',
'E-Commerce Platforms, Retail, SaaS':     'E-commerce',
'E-Commerce, E-Commerce Platforms, Furniture, Home Decor, Internet':     'E-commerce',
'E-Commerce, E-Commerce Platforms, Internet, Mobile Apps, Social Media':     'E-commerce',
'E-Commerce, E-Commerce Platforms, Internet, Retail':     'E-commerce',
'E-Commerce, E-Commerce Platforms, Retail':     'E-commerce',
'E-Commerce, Education, Health Care':     'E-commerce',
'E-Commerce, Facilities Support Services, Procurement, Supply Chain Management':     'E-commerce',
'E-Commerce, Fashion, Jewelry, Retail':     'E-commerce',
'E-Commerce, Fashion, Lifestyle':     'E-commerce',
'E-Commerce, Fashion, Mobile':     'E-commerce',
'E-Commerce, Fashion, Shopping':     'E-commerce',
'E-Commerce, Fitness, Health Care':     'E-commerce',
'E-Commerce, Food and Beverage, Internet':     'E-commerce',
'E-Commerce, Food and Beverage, Tea':     'E-commerce',
'E-Commerce, Food Processing':     'E-commerce',
'E-Commerce, Furniture, Home Decor, Interior Design, Internet':     'E-commerce',
'E-Commerce, Furniture, Interior Design':     'E-commerce',
'E-Commerce, Health Care, Retail':     'E-commerce',
'E-Commerce, Mobile, Retail':     'E-commerce',
'E-Commerce, Mobile, Sharing Economy':     'E-commerce',
'E-Commerce, Retail, Shopping':     'E-commerce',
'EdTech Startup':     'Education Technology(EdTech)',
'EdTech, Education':     'Education Technology(EdTech)',
'EdTech, Education, Enterprise Software, Peer to Peer':     'Education Technology(EdTech)',
'EdTech, Education, Higher Education, Secondary Education':     'Education Technology(EdTech)',
'EdTech, Education, Information Services, SaaS':     'Education Technology(EdTech)',
'EdTech, Education, Knowledge Management':     'Education Technology(EdTech)',
'EdTech, Education, Mobile, Tutoring':     'Education Technology(EdTech)',
'EdtTech':     'Education Technology(EdTech)',
'Education':     'Education Technology(EdTech)',
'Education Management':     'Education Technology(EdTech)',
'Education Technology(EdTech)':     'Education Technology(EdTech)',
'Education, Financial Services, FinTech':     'Education Technology(EdTech)',
'Education, Gaming, Training':     'Education Technology(EdTech)',
'Education, Human Resources':     'Education Technology(EdTech)',
'Education, Information Technology, Internet, Mobile, Software':     'Education Technology(EdTech)',
'E-learning':     'Education Technology(EdTech)',
'E-Learning, EdTech, Education':     'Education Technology(EdTech)',
'E-Learning, EdTech, Education, Image Recognition, Machine Learning, STEM Education':     'Education Technology(EdTech)',
'E-Learning, Education':     'Education Technology(EdTech)',
'E-Learning, Education, Higher Education':     'Education Technology(EdTech)',
'E-Learning, Internet':     'Education Technology(EdTech)',
'E-Learning, Internet, Video Games':     'Education Technology(EdTech)',
'E-market':     'E-commerce',
'Energy, Energy Storage, Infrastructure':     'Renewable Energy',
'Energy, Environmental Consulting, Renewable Energy, Solar':     'Renewable Energy',
'Energy, Natural Resources':     'Renewable Energy',
'Energy, Renewable Energy, Solar':     'Renewable Energy',
'Energy, Solar':     'Renewable Energy',
'Enterprise Resource Planning (ERP), Information Services, Information Technology, Real Estate':     'Technology and Software',
'Environmental Consulting, Renewable Energy':     'Renewable Energy',
'Fashion':     'Fashion and Lifestyle',
'Fashion & Lifestyle':     'Fashion and Lifestyle',
'Fashion and Lifestyle':     'Fashion and Lifestyle',
'Fashion Tech':     'Fashion and Lifestyle',
'Fashion, Graphic Design, Wearables':     'Fashion and Lifestyle',
'Fashion, Jewelry':     'Fashion and Lifestyle',
'Fashion, Lifestyle, Rental':     'Fashion and Lifestyle',
'Fashion, Lifestyle, Retail':     'Fashion and Lifestyle',
'Finance and Fintech':     'Finance and Fintech',
'Finance, Financial Exchanges, Financial Services, Micro Lending':     'Finance and Fintech',
'Finance, Financial Services':     'Finance and Fintech',
'Finance, Financial Services, FinTech':     'Finance and Fintech',
'Finance, Financial Services, Insurance':     'Finance and Fintech',
'Finance, Financial Services, Marketing':     'Finance and Fintech',
'Finance, Financial Services, Small and Medium Businesses':     'Finance and Fintech',
'Finance, FinTech, Mobile Payments':     'Finance and Fintech',
'Finance, FinTech, Payments, Property Development, Rental':     'Finance and Fintech',
'Finance, Impact Investing, Internet':     'Finance and Fintech',
'Finance, Impact Investing, Mobile Apps':     'Finance and Fintech',
'Finance, Internet, Travel':     'Finance and Fintech',
'Financial Services, FinTech':     'Finance and Fintech',
'Financial Services, Insurance, Private Social Networking':     'Finance and Fintech',
'Financial Services, Lending':     'Finance and Fintech',
'Financial Services, Lending, Peer to Peer':     'Finance and Fintech',
'Financial Services, Micro Lending':     'Finance and Fintech',
'Financial Services, Professional Services':     'Finance and Fintech',
'Financial Services, SaaS, Security':     'Finance and Fintech',
'Financial Services, Venture Capital':     'Finance and Fintech',
'FinTech, Internet, Payments, Service Industry':     'Finance and Fintech',
'FinTech, Mobile, Mobile Payments, Payments, Retail Technology':     'Finance and Fintech',
'Food & Beverages':     'Travel and Hospitality',
'Food & Logistics':     'Travel and Hospitality',
'Food & Nutrition':     'Travel and Hospitality',
'Food & tech':     'Travel and Hospitality',
'Food and Beverage':     'Travel and Hospitality',
'Food and Beverage, Food Delivery':     'Travel and Hospitality',
'Food and Beverage, Food Delivery, Snack Food':     'Travel and Hospitality',
'Food and Beverage, Food Processing':     'Travel and Hospitality',
'Food and Beverage, Food Processing, Manufacturing':     'Travel and Hospitality',
'Food and Beverage, Food Processing, Nutrition':     'Travel and Hospitality',
'Food and Beverage, Food Processing, Organic Food, Snack Food':     'Travel and Hospitality',
'Food and Beverage, Restaurants, Tea':     'Travel and Hospitality',
'Food and Beverage, Snack Food':     'Travel and Hospitality',
'Food and Beverage, Snack Food, Tea':     'Travel and Hospitality',
'Food and Beverage, Tea':     'Travel and Hospitality',
'Food delivery':     'Travel and Hospitality',
'Food Delivery, Food Processing, Internet':     'Travel and Hospitality',
'Food Delivery, Hospitality, Reservations, Restaurants, Search Engine':     'Travel and Hospitality',
'Food Delivery, Online Portals, Restaurants':     'Travel and Hospitality',
'Food Delivery, Organic, Organic Food':     'Travel and Hospitality',
'Food devlivery':     'Travel and Hospitality',
'Food diet':     'Travel and Hospitality',
'Food Processing':     'Travel and Hospitality',
'Food Processing, Retail':     'Travel and Hospitality',
'Food Production':     'Travel and Hospitality',
'Food Startup':     'Travel and Hospitality',
'Food tech':     'Travel and Hospitality',
'Foodtech':     'Travel and Hospitality',
'Foodtech & Logistics':     'Travel and Hospitality',
'Health':     'Healthcare and Biotech',
'Health & Wellness':     'Healthcare and Biotech',
'Health and Fitness':     'Healthcare and Biotech',
'Health care':     'Healthcare and Biotech',
'Health Care, Health Diagnostics, Internet of Things, Life Science, Machine Learning, Medical, Medical Device':     'Healthcare and Biotech',
'Health Care, Health Diagnostics, Predictive Analytics':     'Healthcare and Biotech',
'Health Care, Health Insurance':     'Healthcare and Biotech',
'Health Care, Hospital':     'Healthcare and Biotech',
'Health Care, Hospital, Medical':     'Healthcare and Biotech',
'Health Care, Hospital, Medical, Robotics':     'Healthcare and Biotech',
'Health Care, Hospital, Supply Chain Management':     'Healthcare and Biotech',
'Health Care, Hospital, Wellness':     'Healthcare and Biotech',
'Health Care, Hospitality':     'Healthcare and Biotech',
'Health Care, Information Technology':     'Healthcare and Biotech',
'Health Care, Information Technology, Management Information Systems':     'Healthcare and Biotech',
'Health Care, Medical':     'Healthcare and Biotech',
'Health Care, Medical Device, Mobile Apps':     'Healthcare and Biotech',
'Health Care, Medical Device, Public Safety':     'Healthcare and Biotech',
'Health Care, Medical, Pharmaceutical':     'Healthcare and Biotech',
'Health Care, Pharmaceutical, Wellness':     'Healthcare and Biotech',
'Health Diagnostics':     'Healthcare and Biotech',
'Health Insurance, Insurance, Life Insurance':     'Healthcare and Biotech',
'Health, Wellness & Fitness':     'Healthcare and Biotech',
'HealthCare':     'Healthcare and Biotech',
'Healthcare and Biotech':     'Healthcare and Biotech',
'Healthcare/Edtech':     'Healthcare and Biotech',
'Healthtech':     'Healthcare and Biotech',
'Heathcare':     'Healthcare and Biotech',
'HeathTech':     'Healthcare and Biotech',
'Helathcare':     'Healthcare and Biotech',
'Higher Education':     'Education Technology(EdTech)',
'Home Decor':     'Fashion and Lifestyle',
'Home Decor, Home Improvement, Home Renovation, Home Services, Interior Design, Smart Home':     'Fashion and Lifestyle',
'Home Decor, Interior Design':     'Fashion and Lifestyle',
'Home Design':     'Fashion and Lifestyle',
'Home interior services':     'Fashion and Lifestyle',
'Hospital':     'Healthcare and Biotech',
'Hospital & Health Care':     'Healthcare and Biotech',
'Hospitality, Hotel, Leisure, Travel':     'Healthcare and Biotech',
'Hospitality, Information Technology, Travel Accommodations':     'Travel and Hospitality',
'Hospitality, Real Estate':     'Travel and Hospitality',
'Housing':     'Real Estate Tech (PropTech)',
'Housing & Rentals':     'Real Estate Tech (PropTech)',
'Housing Marketplace':     'Real Estate Tech (PropTech)',
'HR':     'E-commerce',
'HR tech':     'E-commerce',
'HR Tech startup':     'E-commerce',
'HrTech':     'E-commerce',
'Human Resources':     'E-commerce',
'Human Resources, Security, Training':     'E-commerce',
'Insurance':     'Finance and Fintech',
'Insurance Tech':     'Finance and Fintech',
'Insurance technology':     'Finance and Fintech',
'InsureTech':     'Finance and Fintech',
'Insurtech':     'Finance and Fintech',
'Interior & decor':     'Fashion and Lifestyle',
'Interior Design':     'Fashion and Lifestyle',
'Internet':     'Manufacturing and Hardware',
'Internet of Things, Robotics':     'Manufacturing and Hardware',
'Internet of Things, Telecommunications':     'Manufacturing and Hardware',
'Internet of Things, Waste Management':     'Manufacturing and Hardware',
'Internet, Knowledge Management':     'Manufacturing and Hardware',
'Internet, Leisure, Marketplace':     'Manufacturing and Hardware',
'Internet, Marketplace, Shopping':     'Manufacturing and Hardware',
'Internet, Mobile Apps, Social Network':     'Manufacturing and Hardware',
'Internet, Mobile, Social Entrepreneurship, Telecommunications, Wireless':     'Manufacturing and Hardware',
'Internet, Social Entrepreneurship':     'Manufacturing and Hardware',
'Internet, Social Network, TV':     'Manufacturing and Hardware',
'Internet, Social News, Sports':     'Manufacturing and Hardware',
'Internet, Software':     'Manufacturing and Hardware',
'Investment':     'Finance and Fintech',
'Investment Banking':     'Finance and Fintech',
'Investment Management':     'Finance and Fintech',
'Investment Tech':     'Finance and Fintech',
'IoT':     'Manufacturing and Hardware',
'IoT platform':     'Manufacturing and Hardware',
'IoT/Automobile':     'Manufacturing and Hardware',
'IT':     'Manufacturing and Hardware',
'IT company':     'Manufacturing and Hardware',
'IT startup':     'Manufacturing and Hardware',
'Jewellery':     'Fashion and Lifestyle',
'Jewellery startup':     'Fashion and Lifestyle',
'Last Mile Transportation, Railroad, Transportation, Travel':     'Legaltech and Govtech',
'Legal':     'Legaltech and Govtech',
'Legal Services':     'Legaltech and Govtech',
'Legal tech':     'Legaltech and Govtech',
'LegalTech':     'Legaltech and Govtech',
'Logistics & Supply Chain':     'Transportation and Logistics',
'Logistics, Railroad, Transportation':     'Transportation and Logistics',
'Logistics, Supply Chain Management':     'Transportation and Logistics',
'Logistics, Transportation, Travel':     'Transportation and Logistics',
'Logitech':     'Transportation and Logistics',
'Machine Learning':     'Manufacturing and Hardware',
'Manufacturing':     'Manufacturing and Hardware',
'Manufacturing and Hardware':     'Manufacturing and Hardware',
'Manufacturing startup':     'Manufacturing and Hardware',
'Manufacturing, Oil and Gas, Robotics':     'Manufacturing and Hardware',
'Manufacturing, Retail':     'Manufacturing and Hardware',
'Market Research':     'Marketing and Advertising Technology',
'Marketing':     'Marketing and Advertising Technology',
'Marketing & Advertising':     'Marketing and Advertising Technology',
'Marketing & Customer loyalty':     'Marketing and Advertising Technology',
'Marketing and Advertising Technology':     'Marketing and Advertising Technology',
'Marketing startup':     'Marketing and Advertising Technology',
'Marketing, Social Media, Video':     'Marketing and Advertising Technology',
'Marketplace':     'Marketing and Advertising Technology',
'Marketplace, Real Estate, Rental Property':     'Marketing and Advertising Technology',
'Media':     'Media and Entertainment',
'Media & Networking':     'Media and Entertainment',
'Media and Entertainment':     'Media and Entertainment',
'Media and Entertainment, News, Outdoors':     'Media and Entertainment',
'Media and Entertainment, News, Publishing':     'Media and Entertainment',
'Media Tech':     'Media and Entertainment',
'Medical':     'Healthcare and Biotech',
'Medical Device':     'Healthcare and Biotech',
'Medical, Tourism':     'Healthcare and Biotech',
'Mental Health':     'Healthcare and Biotech',
'Music':     'Media and Entertainment',
'Music Streaming':     'Media and Entertainment',
'Music, Social Network, Video':     'Media and Entertainment',
'News, Publishing, Social Media':     'Media and Entertainment',
'Nutrition':     'Healthcare and Biotech',
'Nutrition Tech':     'Healthcare and Biotech',
'Oil & Energy':     'Renewable Energy',
'Oil and Energy':     'Renewable Energy',
'Sales & Services':     'Marketing and Advertising Technology',
'Sales and Distribution':     'Marketing and Advertising Technology'


})

# %%
data_final['Sector'].value_counts()
# Out:
# Sector
# Finance and Fintech                                 397
# Education Technology(EdTech)                        278
# Healthcare and Biotech                              224
# E-commerce                                          180
# Travel and Hospitality                              150
#                                                    ...
# Innovation management                                 1
# D2C startup                                           1
# Warehouse                                             1
# CRM                                                   1
# B2B, Business Development, Internet, Marketplace      1
# Name: count, Length: 537, dtype: int64

# %%
# set values to lowercase to improve consistency

data_final['Sector'] = data_final['Sector'].str.lower()

# Remove leading and trailing whitespaces from the sector names to rectify variations caused by extra spaces
data_final['Sector'] = data_final['Sector'].str.strip()

# %%
data_final['Sector'].value_counts()
# Out:
# Sector
# finance and fintech                                 397
# education technology(edtech)                        278
# healthcare and biotech                              224
# e-commerce                                          182
# travel and hospitality                              150
#                                                    ...
# taas startup                                          1
# b2b manufacturing                                     1
# delivery service                                      1
# social audio                                          1
# b2b, business development, internet, marketplace      1
# Name: count, Length: 525, dtype: int64

# %%
# split Sector into list and keep first item of the sector name
data_final['Sector'] = data_final['Sector'].str.split(',').str[0]

# %%
data_final['Sector'].nunique()
# Out:
# 385

# %%
# Replace '-' in the sector column with NaN since that entry cannot be defined.
data_final['Sector'] = data_final['Sector'].replace('—', np.nan)

# %% [markdown]
# Cleaning the Stage column

# %%
# get unique values for'Stage' stage column
data_final['Stage'].unique()
# Out:
# array([None, 'Pre-seed', 'Seed', 'Pre-series A', 'Pre-series', 'Series C',
#        'Series A', 'Series B', 'Debt', 'Pre-series C', 'Pre-series B',
#        'Series E', 'Bridge', 'Series D', 'Series B2', 'Series F',
#        'Pre- series A', 'Edge', 'Series H', 'Pre-Series B', 'Seed A',
#        'Series A-1', 'Seed Funding', 'Pre-Seed', 'Seed round',
#        'Pre-seed Round', 'Seed Round & Series A', 'Pre Series A',
#        'Pre seed Round', 'Angel Round', 'Pre series A1', 'Series E2',
#        'Pre series A', 'Seed Round', 'Bridge Round', 'Pre seed round',
#        'Pre series B', 'Pre series C', 'Seed Investment', 'Series D1',
#        'Mid series', 'Series C, D', 'Seed funding', '$1200000', 'Seed+',
#        'Series F2', 'Series A+', 'Series G', 'Series B3', 'PE',
#        'Series F1', 'Pre-series A1', '$300000', 'Early seed', '$6000000',
#        '$1000000', 'Seies A', 'Series A2', 'Series I', nan,
#        'Fresh funding', 'Post series A', 'Seed fund', 'Series B+',
# ...

# %%
#convert enteries to lowercase to make analysis easier
data_final['Stage'] = data_final['Stage'].str.lower()

# %%
# Standardize specific enteries in the Stage column to ensure consistency
data_final['Stage'] = data_final['Stage'].replace({
    "pre series": "pre-series",
    "pre- series": "pre-series",
    "a-1": "a1",
    "pre seed": "pre-seed",
    "seies": "series",
    "https://docs.google.com/spreadsheets/d/1x9ziNeaz6auNChIHnMI8U6kS7knTr3byy_YBGfQaoUA/edit#gid=1861303593": "nan",
    "pre- series a": "pre-series a",
    "series a-1": "series a1",
    "seies a": "series a",
    "venture - series unknown": "venture-series unknown"})

# %%
# Replace '$1200000' in the stage column with None since that entry is not a stage.
data_final['Stage'] = data_final['Stage'].replace('$1200000', None)

# Replace '$300000' in the stage column with None since that entry is  not a stage.
data_final['Stage'] = data_final['Stage'].replace('$300000', None)

# Replace '$600000' in the stage column with None since that entry is not a stage .
data_final['Stage'] = data_final['Stage'].replace('$6000000', None)

# Replace '$1000000' in the stage column with None since that entry is not a stage.
data_final['Stage'] = data_final['Stage'].replace('$1000000', None)

# %%
data_final['Stage'].unique()
# Out:
# array([None, 'pre-seed', 'seed', 'pre-series a', 'pre-series', 'series c',
#        'series a', 'series b', 'debt', 'pre-series c', 'pre-series b',
#        'series e', 'bridge', 'series d', 'series b2', 'series f', 'edge',
#        'series h', 'seed a', 'series a1', 'seed funding', 'seed round',
#        'pre-seed round', 'seed round & series a', 'pre series a',
#        'pre seed round', 'angel round', 'pre series a1', 'series e2',
#        'bridge round', 'pre series b', 'pre series c', 'seed investment',
#        'series d1', 'mid series', 'series c, d', 'seed+', 'series f2',
#        'series a+', 'series g', 'series b3', 'pe', 'series f1',
#        'pre-series a1', 'early seed', 'series a2', 'series i', nan,
#        'fresh funding', 'post series a', 'seed fund', 'series b+',
#        'angel', 'private equity', 'venture-series unknown', 'grant',
#        'debt financing', 'post-ipo debt', 'corporate round',
#        'undisclosed',
# ...

# %%
# check for null values again
data_final.isnull().sum()
# Out:
# Company Brand       0
# Founded           769
# HeadQuarter       114
# Sector             48
# What it does        0
# Founders          545
# Investor          625
# Amount($)        1591
# Stage             934
# Year Funded         0
# dtype: int64

# %%
#install seaborn
# %pip install seaborn


#import modules 
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Check for missing values
print(data_final.isnull().sum())

# Visualize missing values using a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(data_final.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

# Handle missing values (e.g., drop columns, impute values)
# df.dropna(inplace=True)  # Drop rows with missing values
# df['column_name'].fillna(df['column_name'].mean(), inplace=True)  # Impute missing values
# Out:
# Company Brand       0
# Founded           769
# HeadQuarter       114
# Sector             48
# What it does        0
# Founders          545
# Investor          625
# Amount($)        1591
# Stage             934
# Year Funded         0
# dtype: int64

# %% [markdown]
# Handling missing values

# %%
# Remove commas and convert 'Amount' column to numeric
data_final['Amount($)'] = pd.to_numeric(data_final['Amount($)'].str.replace(',', ''), errors='coerce')

# Check for skewness
amount_skewness = data_final['Amount($)'].skew()

# Display skewness for the 'Amount' column
print("Skewness for the 'Amount($)' column:", amount_skewness)
# Out:
# Skewness for the 'Amount($)' column: 4.327377757827879

# %% [markdown]
# A skewness value of 4.3274 indicates that the distribution is highly positively skewed. Positive skewness means that the right tail of the distribution is longer or fatter than the left tail, and the majority of the data points are concentrated on the left side. This practically means that  there are extreme values or outliers on the right side of the distribution, pulling the mean and the tail in that direction. Filling null values with the median is the best option in this case.

# %%
amount_median = data_final['Amount($)'].median()
data_final['Amount($)'].fillna(amount_median, inplace=True)

# %% [markdown]
# Mode imputation is a simple method that doesn't introduce much complexity to the data and imputing missing values with the mode won't significantly impact the analysis. It will also ensure that the imputed values align with the overall distribution of the sector column.

# %%
# Calculate the mode of the 'Sector' column
mode_sector = data_final['Sector'].mode()[0]

# Fill missing values with the mode
data_final['Sector'].fillna(mode_sector, inplace=True)

# %%
# dealing with missing values in 'HeadQuarter' column

data_final['HeadQuarter'].fillna("Not Specified", inplace=True)

# %%
# Calculate the mode of the 'Stage' column
mode_stage = data_final['Stage'].mode()[0]

# Fill missing values with the mode
data_final['Stage'].fillna(mode_stage, inplace=True)

# %%
# check for number of missing values

data_final.isnull().sum()
# Out:
# Company Brand      0
# Founded          769
# HeadQuarter        0
# Sector             0
# What it does       0
# Founders         545
# Investor         625
# Amount($)          0
# Stage              0
# Year Funded        0
# dtype: int64

# %% [markdown]
# Founded, Investor and Founders columns are dropped because they are not relevant for the analysis

# %%
#drop Founded column
data_final = data_final.drop(columns='Founded')

# %%
#drop Founders column

data_final = data_final.drop(columns='Founders')

# %%
#drop Investor column

data_final = data_final.drop(columns='Investor')

# %%
#get data shape
data_final.shape
# Out:
# (2857, 7)

# %%
data_final['Stage'].describe()
# Out:
# count     2857
# unique      63
# top       seed
# freq      1534
# Name: Stage, dtype: object

# %% [markdown]
# # Answering Business Questions
# 1. What top 10 sectors have received the highest amount of funding

# %%
#plot a bar chart showing the top 10 sectors with highest amount of funding

top_sectors = data_final.groupby('Sector')['Amount($)'].sum().nlargest(10)

plt.figure(figsize=(12, 6))
sns.barplot(x=top_sectors.values, y=top_sectors.index, palette='magma')
plt.title('Top 10 Sectors by Funding Amount')
plt.xlabel('Total Funding Amount ($)')
plt.ylabel('Sector')
plt.show()

# %% [markdown]
# This plot highlights the Top 10 sectors which received the most amounts of funding. We can confidently say that these sectors had the most attractive opportunities for both investors and founders with EdTech being on top of the list
#
#
#
# 2.  Which sectors have received lowest amounts of funding

# %%
# Group by sector and calculate the total funding for each sector
sector_funding = data_final.groupby('Sector')['Amount($)'].sum()

# Sort sectors by total funding in ascending order and select the top 10
top_10_lowest_sectors = sector_funding.sort_values().head(10)

# Create a bar plot
plt.figure(figsize=(12, 6))
top_10_lowest_sectors.plot(kind='bar', color='skyblue')
plt.title('Top 10 Sectors with Lowest Funding')
plt.xlabel('Sector')
plt.ylabel('Total Funding Amount ($)')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# From the above plot, it is evident that these sectors received the lowest amount of funding and are therefore not advisable opportunities for both investors and startup founders.
#
#
#
#
#
# 3. What is the average amount of funding a startup can receive in the Indian ecosystem

# %%
# Calculate the average funding amount
average_funding = data_final['Amount($)'].mean()
average_funding
# Out:
# 7006101.925096255

# %% [markdown]
# The output above shows that the average amount of funding received by Indian startups is about $7 million.This amount is considerably high and shows that investors generally have a high confidence in startups and the overall business environment in India.

# %% [markdown]
# 4. Which funding stages tend to receive the highest amount of funding

# %%
# Group by Stage and calculate the sum of Amount
total_amount_by_stage = data_final.groupby('Stage')['Amount($)'].sum().sort_values(ascending=False)

# Select top 10 funding stages
top_10_stages = total_amount_by_stage.head(10)

# Plotting
plt.figure(figsize=(12, 6))
sns.barplot(x=top_10_stages.index, y=top_10_stages.values, palette='viridis')
plt.title('Top 10 Funding Stages by Total Amount')
plt.xlabel('Funding Stage')
plt.ylabel('Total Amount ($)')
plt.xticks(rotation=45, ha='right')  

# Show the plot
plt.show()

# %% [markdown]
# It is obvious from the above plot that the 'Seed' stage received the most amount of funding. Understanding which stages attract more funding can provide insights into the competitive landscape and aid our decision as startups

# %% [markdown]
# 5. Which location of HeadQuarters in India have the highest concentration of highly funded startups

# %%
# Group data by 'HeadQuarter' and calculate the total funding for each location
location_total_funding = data_final.groupby('HeadQuarter')['Amount($)'].sum().sort_values(ascending=False)

# Select the top N locations, for example, the top 10
top_locations = location_total_funding.head(10)

# Plot the data
plt.figure(figsize=(12, 6))
sns.barplot(x=top_locations.values, y=top_locations.index, palette='inferno')  

# Customize the plot
plt.title('Top 10 Locations by Total Funding')
plt.xlabel('Total Funding Amount ($)')
plt.ylabel('Location')

# Show the plot
plt.show()

# %% [markdown]
# High funding amounts in specific locations may indicate vibrant startup ecosystems or the presence of key industry players.From the above plot, it can be seen that Bangalore has the highest concentration of successful startups with regards to funding amounts.

# %% [markdown]
# 6. What is the overall trend in funding for Indian startups between 2018 and 2021

# %%
total_funding_per_year = data_final.groupby('Year Funded')['Amount($)'].sum().reset_index()

# Plotting the trend
plt.figure(figsize=(10, 6))
sns.lineplot(x='Year Funded', y='Amount($)', data=total_funding_per_year, marker='o')
plt.title('Overall Trend in Funding for Indian Startups (2018-2021)')
plt.xlabel('Year')
plt.ylabel('Total Funding Amount ($)')
plt.show()

# %%
#extract data in csv file
data_final.to_csv('documents.csv', index=True)

# %% [markdown]
# From the line plot above, it can be seen that the amounts of funding received by Indian Startups increased considerably as the years went by (2018-2021).
